# %% [markdown]
# <a href="https://colab.research.google.com/github/tuckertrostbyui/cs210-projects/blob/main/starter_bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import tree
import sklearn.metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

campaign = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank.csv')

# %%
campaign
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 37064   73      retired  married  professional.course       no     yes   no
# 37065   46  blue-collar  married  professional.course       no      no   no
# 37066   56      retired  married    university.degree       no     yes   no
# 37067   44   technician  married  professional.course       no      no   no
# 37068   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
features = campaign.iloc[:, :19]
X = pd.get_dummies(features,drop_first=True)
y = campaign['y'].map({'yes': 1, 'no': 0})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state = 42)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_train_sm, y_train_sm = sm.fit_resample(X_train,y_train)

smote_model = rf.fit(X_train_sm,y_train_sm)

smote_model
# Evaluate the model
y_pred_imp = rf.predict(X_test)
print("Updated Model Performance:")
print("Accuracy:", accuracy_score(y_test, y_pred_imp))
print("Precision:", precision_score(y_test, y_pred_imp))
print("Recall:", recall_score(y_test, y_pred_imp))
print("F1-Score:", f1_score(y_test, y_pred_imp))
print("ROC-AUC:", roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1]))
# Out:
# Updated Model Performance:
# Accuracy: 0.8643107634205557
# Precision: 0.44021101992966
# Recall: 0.5754789272030651
# F1-Score: 0.49883759548322815
# ROC-AUC: 0.7917233026382762

# %%
rf = RandomForestClassifier(max_depth = 10,min_samples_leaf=2,min_samples_split=2,random_state=42)

rf.fit(X_train,y_train)

rf.score(X_test,y_test)
# Out:
# 0.897131552917903

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Evaluate the model
y_pred_imp = rf.predict(X_test)
print("Updated Model Performance:")
print("Accuracy:", accuracy_score(y_test, y_pred_imp))
print("Precision:", precision_score(y_test, y_pred_imp))
print("Recall:", recall_score(y_test, y_pred_imp))
print("F1-Score:", f1_score(y_test, y_pred_imp))
print("ROC-AUC:", roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1]))
# Out:
# Updated Model Performance:
# Accuracy: 0.897131552917903
# Precision: 0.6842105263157895
# Recall: 0.22911877394636015
# F1-Score: 0.34328358208955223
# ROC-AUC: 0.8032942541225991

# %%
import plotly.express as px
features_top = pd.DataFrame(rf.feature_importances_, index=X.columns, columns=['importance']).sort_values(by='importance', ascending=False)

# Narrow down to top 10
features10 = features_top.head(10).sort_values(by='importance', ascending=True)

# Top 10 chart
feat_fig = px.bar(features10, x='importance', y=features10.index, labels = {'index': 'feature'}, title='Most Important Features')
feat_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
